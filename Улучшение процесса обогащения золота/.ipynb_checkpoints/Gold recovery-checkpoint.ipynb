# %% [markdown]
# # Улучшение процесса обогащения золота

# %% [markdown]
# Gредоставлены следующие данные:
#
# gold_recovery_train_new.csv — обучающая выборка;
# gold_recovery_test_new.csv — тестовая выборка;
# gold_recovery_full_new.csv — исходные данные.
#
# Цель: выполнить прототип модели машинного обучения для предсказания коэффициента восстановления золота из золотосодержащей руды для оптимизации производства (чтобы не запускать предприятие с убыточными характеристиками).
#
# Задачи:
#
# 1. Подготовить данные (выполнить предобработку данных);
# 2. Провести исследовательский анализ данных;
#    2.1. Изучить изменение концентрации металлов (Au, Ag, Pb) на различных этапах очистки.
#    2.2. Сравнить распределения размеров гранул сырья на обучающей и тестовой выборках.
#    2.3. Исследовать суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.
# 3. Построить и обучить модель.

# %% [markdown]
# ## 1.1 Подготовка данных

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from tqdm.notebook import tqdm

from sklearn.model_selection import train_test_split
from sklearn.pipeline import  make_pipeline

from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_absolute_error, make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.dummy import DummyRegressor

import warnings
warnings.filterwarnings("ignore")

# %%
df_train = pd.read_csv('C:/Users/Lubov/jupyter/ds/gold_recovery_train_new.csv')
df_test = pd.read_csv('C:/Users/Lubov/jupyter/ds/gold_recovery_test_new.csv')
df_full = pd.read_csv('C:/Users/Lubov/jupyter/ds/gold_recovery_full_new.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
df_train.name = 'df_train'
df_test.name = 'df_test'
df_full.name = 'df_full'

# %%
for df in [df_train, df_test, df_full]:#посмотрю данные
    display (df.name)
    display(df.head())
    print()
    df.info()
    print('Кол-во дубликатов =', df.duplicated().sum())
    print()
    display('Кол-во пропусков:', df.isna().sum())
    display(df.describe())
    print('_____________________________________________________________________________')
# Out:
# 'df_train'
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %% [markdown]
# После изучения файлов стоит отметить, что в данных есть пропуски, отсутствуют дубликаты.
# В данных df_test нет некоторых признаков, которые есть в df_full и df_train.

# %% [markdown]
# ### 1.2 Проверим правильность расчета эффективности обогащения

# %% [markdown]
# Рассчитаю эффективность обогащения для золота:

# %%
df_train['RECOVERY'] = (df_train['rougher.output.concentrate_au']*\
                       (df_train['rougher.input.feed_au']-df_train['rougher.output.tail_au']))/\
                       (df_train['rougher.input.feed_au']*(df_train['rougher.output.concentrate_au']-\
                        df_train['rougher.output.tail_au']))*100

df_train['RECOVERY'].head()
# Out:
# 0    87.107763
# 1    86.843261
# 2    86.842308
# 3    87.226430
# 4    86.688794
# Name: RECOVERY, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(df_train['rougher.output.recovery'], df_train['RECOVERY'])
# Out:
# 9.73512347450521e-15

# %% [markdown]
# Вывод:
#
# Значениями  rougher.output.recovery и мой расчет практически совпали, среднее абсолютное отклонение (МАЕ) очень мало - 9.7e-15
# Получается, коэффициент обогащения для процесса флотации рассчитан верно.

# %% [markdown]
# ### 1.3 Проанализирую признаки, недоступные в тестовой выборке.

# %% [markdown]
# Рассмотрю столбцы, которые есть в  df_full и df_train, но отсутствуют в df_test.

# %%
set(df_full.columns).symmetric_difference(df_train.columns)
# Out:
# {'RECOVERY'}

# %% [markdown]
# Признаки df_train и df_full совпадают.

# %%
set(df_full.columns).symmetric_difference(df_test.columns)
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# Вывод:
# Почти все признаки, отсутствующие в df_test, имеют тип output (параметры продукта), за исключением 4 шт - типа calculation (расчётные характеристики), эти данные получаю по факту, поэтому логично, что они отсутствуют в df_test.

# %% [markdown]
# ### 1.4. Предобработка данных

# %% [markdown]
# В df_train есть 2 целевых столбца rougher.output.recovery и final.output.recovery.
# В дальнейшем надо в df_test добавить целевые признаки из df_full и на этапе обучения из df_train удалить признаки, которых нет в df_test. Добавляю в df_test целевые признаки из df_full по совпадению даты

# %%
df_full_target=df_full[['date','rougher.output.recovery','final.output.recovery']]
df_full_target.head()
# Out:
#                   date  rougher.output.recovery  final.output.recovery
# 0  2016-01-15 00:00:00                87.107763              70.541216
# 1  2016-01-15 01:00:00                86.843261              69.266198
# 2  2016-01-15 02:00:00                86.842308              68.116445
# 3  2016-01-15 03:00:00                87.226430              68.347543
# 4  2016-01-15 04:00:00                86.688794              66.927016

# %%
df_test = df_test.merge(df_full_target, on='date', how='left')
df_test.head()#проверка
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %% [markdown]
# Пропуски заполню соседними, так как по условию задачи "Соседние по времени параметры часто похожи".

# %%
df_train = df_train.fillna(method='ffill')#заполняю следующим непропущенным значением
df_test = df_test.fillna(method='ffill')

print(df_train.isna().sum().sum())#проверка способ 1
df_test.isna().values.any()#проверка способ 2
# Out:
# 0
# False

# %% [markdown]
# ### 1.5 Вывод:

# %% [markdown]
# Изучила данные.
# Подтвердила правильность расчета эффективности обогащения в тренировочной выборке.
# На этапе предобработки избавилась от пропусков в тренировочной и тестовой выборках, добавила признаки в тестовую выборку.

# %% [markdown]
# ## 2. Анализ данных

# %% [markdown]
# ### 2.1. Посмотрю как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки.

# %% [markdown]
# Всего выделено 4 этапа обработки: флотация, первичная очистка, вторичная очистка, финальный концентрат.
#
# - rougher.input.feed - параметры сырья до флотации
# - rougher.output.concentrate - параметры продукта после флотации
# - primary_cleaner.output.concentrate - параметры продукта после первичной очистки
# - final.output.concentrate - финальные характеристики продукта (после вторичной очистки)

# %% [markdown]
# 1. Золото

# %%
concentrate_au = df_full[['rougher.input.feed_au',
                       'rougher.output.concentrate_au',
                       'primary_cleaner.output.concentrate_au',
                       'final.output.concentrate_au'
                      ]].mean(axis=0)
concentrate_au
# Out:
# rougher.input.feed_au                     8.266097
# rougher.output.concentrate_au            19.772000
# primary_cleaner.output.concentrate_au    32.119400
# final.output.concentrate_au              44.076513
# dtype: float64

# %% [markdown]
# 2. Серебро

# %%
concentrate_ag = df_full[['rougher.input.feed_ag',
                       'rougher.output.concentrate_ag',
                       'primary_cleaner.output.concentrate_ag',
                       'final.output.concentrate_ag'
                      ]].mean(axis=0)
concentrate_ag
# Out:
# rougher.input.feed_ag                     8.794927
# rougher.output.concentrate_ag            11.994759
# primary_cleaner.output.concentrate_ag     8.442408
# final.output.concentrate_ag               5.168470
# dtype: float64

# %% [markdown]
# 3. Свинец

# %%
concentrate_pb = df_full[['rougher.input.feed_pb',
                       'rougher.output.concentrate_pb',
                       'primary_cleaner.output.concentrate_pb',
                       'final.output.concentrate_pb'
                      ]].mean(axis=0)
concentrate_pb
# Out:
# rougher.input.feed_pb                    3.598085
# rougher.output.concentrate_pb            7.606272
# primary_cleaner.output.concentrate_pb    9.829530
# final.output.concentrate_pb              9.978895
# dtype: float64

# %% [markdown]
# По представленным выше данным отчетливо видно, что с каждым этапом увеличивается концентрация золата и свинца, так же можно заметить уменьшение концентрации серебра.
#
# Посмотрю на распределение данных

# %%
position = 0
plt.figure(figsize=[15, 17])

for metal in ['au', 'ag', 'pb']:
    position += 1
    plt.subplot(3, 1, position)
    plt.title(f'График распределения {str(metal).upper()} в различных технологических процессах', fontsize=13)
    sns.set_style('darkgrid')
    sns.histplot(df_train[f'rougher.input.feed_{metal}'], color='y', label='Параметры сырья до флотации', kde=False)
    sns.histplot(df_train[f'rougher.output.concentrate_{metal}'], color='b', label='Параметры продукта после флотации', kde=False)
    sns.histplot(df_train[f'primary_cleaner.output.concentrate_{metal}'], color='g', label='Параметры продукта после первичной очистки', kde=False)
    sns.histplot(df_train[f'final.output.concentrate_{metal}'], color='r', label='Финальные характеристики металла',kde=False)
    plt.xlabel('Концентрация металла')
    plt.ylabel('Количество наблюдений')
    plt.legend()
plt.show();

# %% [markdown]
# Вывод:
#
# - Золото
# Концентрация растет с каждый последующим этапом
#
# - Серебро
# Концентрация падает на этапе флотации, нужно пересматривать технологию, возможно большое кол-во серебра остается в отвальных хвостах
#
# - Свинец
# Концентрация растет с каждый последующим этапом, но медленнее, чем у золота
#
# Также по графикам видны пики около 0, возможно это выбросы, буду смотреть далее.

# %% [markdown]
# ### 2.2.  Сравним распределение размеров гранул сырья на обучающей и тестовой выборках.

# %%
feed_size_train = df_train['rougher.input.feed_size']
feed_size_test = df_test['rougher.input.feed_size']

plt.hist(feed_size_train, bins=100, color='green', label='train', range=(20, 220), alpha=0.5, density=True)
plt.hist(feed_size_test, bins=100, color='blue', label='test', range=(20, 220), alpha=0.5, density=True)
plt.rcParams['figure.figsize'] = (20, 5)
plt.legend(loc='upper left')
plt.title('Распределения размеров гранул сырья на обучающей и тестовой выборках на этапе флотации')
plt.xlabel('Значения')
plt.ylabel('Плотность вероятности')
plt.show()

# %%
feed_size_train_cl = df_train['primary_cleaner.input.feed_size']
feed_size_test_cl = df_test['primary_cleaner.input.feed_size']

plt.hist(feed_size_train_cl, bins=100, color='green', label='train', range=(4, 10), alpha=0.5, density=True)
plt.hist(feed_size_test_cl, bins=100, color='blue', label='test', range=(4, 10), alpha=0.5, density=True)
plt.rcParams['figure.figsize'] = (20, 5)
plt.legend(loc='upper left')
plt.title('Распределения размеров гранул сырья на обучающей и тестовой выборках на этапе первичной очистки')
plt.xlabel('Значения')
plt.ylabel('Плотность вероятности')
plt.show()

# %% [markdown]
# Вывод:
#
# Визуально тренировочные и тестовые распределения похожи.
# Этап флотации: размеры гранул на обучающей выборке - до 55, на тестовой - до 45.
# Этап первичной очистки: размеры гранул на обучающей выборке - до 7.5, на тестовой - до 7.7.

# %% [markdown]
# ### 2.3. Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах

# %% [markdown]
# Напомню 4 этапа обработки:
#
# rougher.input.feed - параметры сырья до флотации
# rougher.output.concentrate - параметры продукта после флотации
# primary_cleaner.output.concentrate - параметры продукта после первичной очистки
# final.output.concentrate - финальные характеристики продукта (после вторичной очистки)

# %%
concentrate_rougher_input = df_full['rougher.input.feed_au']+df_full['rougher.input.feed_ag']+df_full['rougher.input.feed_pb']+df_full['rougher.input.feed_sol']
concentrate_rougher_output = df_full['rougher.output.concentrate_au']+df_full['rougher.output.concentrate_ag']+df_full['rougher.output.concentrate_pb']+df_full['rougher.output.concentrate_sol']
concentrate_primary_cleaner_output = df_full['primary_cleaner.output.concentrate_au']+df_full['primary_cleaner.output.concentrate_ag']+df_full['primary_cleaner.output.concentrate_pb']+df_full['primary_cleaner.output.concentrate_sol']
concentrate_final_output = df_full['final.output.concentrate_au']+df_full['final.output.concentrate_ag']+df_full['final.output.concentrate_pb']+df_full['final.output.concentrate_sol']

# %% [markdown]
# Посмотрю средние значения

# %%
concentrate_rougher_input.mean()
# Out:
# 57.407925923279585

# %%
concentrate_rougher_output.mean()
# Out:
# 68.18891387342029

# %%
concentrate_final_output.mean()
# Out:
# 68.72756159662566

# %%
#строю гистограммы по стадиям:

plt.hist(concentrate_rougher_input, bins=150, color='orange', label='rougher.input', range=(0, 90), alpha=0.5)
plt.hist(concentrate_rougher_output, bins=150, color='blue', label='rougher.output', range=(0, 90), alpha=0.5)
plt.hist(concentrate_primary_cleaner_output, bins=150, color='grey', label='primary_cleaner.output', range=(0, 90), alpha=0.5)
plt.hist(concentrate_final_output, bins=150, color='green', label='final.output', range=(0, 90), alpha=0.5)

plt.rcParams['figure.figsize'] = (20, 5)
plt.legend(loc='upper left')
plt.title('Распределения суммарной концентрации всех веществ на разных стадиях')
plt.xlabel('Количество')
plt.ylabel('Значения')
plt.show()

# %% [markdown]
# Вывод:
#
# Распределения похожи на нормальные, но есть выбросы около 0, может быть это заборы грунта, в которых не было искомых целевых веществ, удалю их.
#
# На финальном этапе распределение болеее узкое, значения варьируются от 57-77, максимум - 69.

# %%
df = pd.concat([concentrate_rougher_input, concentrate_rougher_output, concentrate_primary_cleaner_output, concentrate_final_output], axis=1)
df.columns = ['concentrate_rougher_input', 'concentrate_rougher_output', 'concentrate_primary_cleaner_output', 'concentrate_final_output']
ax = df.boxplot()
ax.get_figure().suptitle(t='Диаграмма рассеяния суммарной концентрации на каждом этапе', fontsize=16);
plt.ylabel("Значения");

# %%
ax = df.boxplot(showfliers=False)#посмотрю без выбросов
ax.get_figure().suptitle(t='Диаграмма рассеяния суммарной концентрации на каждом этапе', fontsize=16);
plt.ylabel("Значения");

# %%
#сделала столбцы с суммарной концентрацией веществ на каждом этапе
df_full['concentrate_rougher_input_all'] = df_full['rougher.input.feed_au']+df_full['rougher.input.feed_ag']+\
                                           df_full['rougher.input.feed_pb']+df_full['rougher.input.feed_sol']
df_full['concentrate_rougher_output_all'] = df_full['rougher.output.concentrate_au']+df_full['rougher.output.concentrate_ag']+\
                                        df_full['rougher.output.concentrate_pb']+df_full['rougher.output.concentrate_sol']
df_full['concentrate_primary_cleaner_output_all'] = df_full['primary_cleaner.output.concentrate_au']+\
                                                df_full['primary_cleaner.output.concentrate_ag']+\
                                                df_full['primary_cleaner.output.concentrate_pb']+\
                                                df_full['primary_cleaner.output.concentrate_sol']
df_full['concentrate_final_output_all'] = df_full['final.output.concentrate_au']+df_full['final.output.concentrate_ag']+\
                                      df_full['final.output.concentrate_pb']+df_full['final.output.concentrate_sol']

df_train['concentrate_rougher_input_all'] = df_train['rougher.input.feed_au']+df_train['rougher.input.feed_ag']+\
                                           df_train['rougher.input.feed_pb']+df_train['rougher.input.feed_sol']
df_train['concentrate_rougher_output_all'] = df_train['rougher.output.concentrate_au']+df_train['rougher.output.concentrate_ag']+\
                                        df_train['rougher.output.concentrate_pb']+df_train['rougher.output.concentrate_sol']
df_train['concentrate_primary_cleaner_output_all'] = df_train['primary_cleaner.output.concentrate_au']+\
                                                df_train['primary_cleaner.output.concentrate_ag']+\
                                                df_train['primary_cleaner.output.concentrate_pb']+\
                                                df_train['primary_cleaner.output.concentrate_sol']
df_train['concentrate_final_output_all'] = df_train['final.output.concentrate_au']+df_train['final.output.concentrate_ag']+\
                                      df_train['final.output.concentrate_pb']+df_train['final.output.concentrate_sol']

# %%
#удалила строки. где суммарная концентрация веществ на каждом этапе равна 0-1
df_full = df_full[(df_full['concentrate_final_output_all'] >= 1) &\
                  (df_full['concentrate_rougher_output_all'] >= 1)&\
                  (df_full['concentrate_primary_cleaner_output_all'] >= 1) &\
                  (df_full['concentrate_final_output_all'] >= 1)] 
                  
df_train = df_train[(df_train['concentrate_final_output_all'] >= 1) &\
                    (df_train['concentrate_rougher_output_all'] >= 1)&\
                    (df_train['concentrate_primary_cleaner_output_all'] >= 1) &\
                    (df_train['concentrate_final_output_all'] >= 1)]

# %% [markdown]
# ### 2.4 Вывод

# %% [markdown]
# Золото:
# Концентрация стремительно растет от процесса к процессу
#
# Серебро:
# Концентрация уменьшается с флотации.
#
# Свинец:
# Концентрация растет от этапа к этапу, но не так быстро, как у золота.
#
# Этап флотации: размеры гранул на обучающей выборке - до 55, на тестовой - до 45. Этап первичной очистки: размеры гранул на обучающей выборке - до 7.5, на тестовой - до 7.7.
#
# Распределения суммарной концентрации всех веществ похожи на нормальные. На финальном этапе распределение болеее узкое, знчения варьируются от 57-77, максимум - 69.
#
# Удалила выброс у нуля у концентраций.

# %% [markdown]
# ## 3. Построение модели. Функция для вычисления sMAPE. Обучение моделей и их качество. Выбор лучшей модели

# %% [markdown]
# ### 3.1. Функция для вычисления итоговой sMAPE

# %%
#создаю функцию для вычисления sMAPE:
def sMAPE_calc(y_target, y_predict):
    smape = np.mean(abs(y_target - y_predict) / ((abs(y_target) + abs(y_predict)) / 2)) * 100
    return smape

# %%
#создаю функцию для вычисления финального sMAPE:
def final_sMAPE_calc(smape_rougher, smape_final):
    return (0.25*smape_rougher + 0.75*smape_final)

# %% [markdown]
# ### 3.2 Обучение моделей и их качество. Выбор лучшей модели

# %%
features_train = df_train[df_test.columns].drop(['date', 'rougher.output.recovery', 'final.output.recovery'], axis=1)#удаляю из трейна столбцы, которых нет в тесте

# %%
columns_list_test = df_test.columns.to_list()#проверка различия стобцов
columns_list_train = df_train.columns.to_list()
for i in columns_list_test:
    if i not in columns_list_train:
        print (i)

# %%
target_train_rougher = np.array(df_train['rougher.output.recovery'])
target_train_final = np.array(df_train['final.output.recovery'])

# %%
for n in [features_train, target_train_rougher, target_train_final]:
    print(n.shape)
# Out:
# (13599, 52)
# (13599,)
# (13599,)

# %%
target_test_rougher = np.array(df_test['rougher.output.recovery'])
target_test_final = np.array(df_test['final.output.recovery'])
features_test = np.array(df_test.drop(['date', 'rougher.output.recovery', 'final.output.recovery'], axis=1))

# %%
for t in [features_test, target_test_rougher, target_test_final]:
    print(t.shape)
# Out:
# (5290, 52)
# (5290,)
# (5290,)

# %%
smape_scorer = make_scorer(sMAPE_calc, greater_is_better=False)

# %% [markdown]
# Модель линейной регрессии

# %%
model_lr = LinearRegression()
parameters_reg = {
    'fit_intercept': [True, False],
    'normalize': [True, False],
    'copy_X': [True, False]
}

# %%
grid_lr_rougher = GridSearchCV(model_lr, 
                             parameters_reg, 
                             cv=5, 
                             scoring=smape_scorer)
grid_lr_rougher.fit(features_train, target_train_rougher)
print(grid_lr_rougher.best_params_)
print('Средняя оценка качества sMape_rougher берем по модулю', abs(grid_lr_rougher.best_score_))
# Out:
# {'copy_X': True, 'fit_intercept': True, 'normalize': False}
# Средняя оценка качества sMape_rougher берем по модулю 7.28213856067291

# %%
grid_lr_final = GridSearchCV(model_lr, 
                             parameters_reg, 
                             cv=5, 
                             scoring=smape_scorer)

grid_lr_final.fit(features_train, target_train_final)
print(grid_lr_final.best_params_)
print('Средняя оценка качества sMape_final берем по модулю', abs(grid_lr_final.best_score_))
# Out:
# {'copy_X': True, 'fit_intercept': False, 'normalize': True}
# Средняя оценка качества sMape_final берем по модулю 10.961807244120703

# %%
total_smape = final_sMAPE_calc(abs(grid_lr_rougher.best_score_), abs(grid_lr_final.best_score_))
print('По модели линейной регрессии итоговое sMAPE =', total_smape)
# Out:
# По модели линейной регрессии итоговое sMAPE = 10.041890073258754

# %% [markdown]
# Модель Случайный лес

# %%
model_rf = RandomForestRegressor(random_state=12345)

# %%
from tqdm import tqdm
from time import sleep

from tqdm.notebook import tqdm

parametrs={'max_depth':[x for x in range(2, 10, 2)],
          'n_estimators': [x for x in range(10, 70, 10)]}

grid_rf_rougher = GridSearchCV(model_rf, 
                             parametrs, 
                             cv=5,
                             scoring=smape_scorer)

grid_rf_rougher.fit(features_train, target_train_rougher)

print(grid_rf_rougher.best_params_)
print('Средняя оценка качества sMape_rougher берем по модулю', abs(grid_rf_rougher.best_score_))
# Out:
# {'max_depth': 6, 'n_estimators': 50}
# Средняя оценка качества sMape_rougher берем по модулю 6.356112714458618

# %%
parametrs={'max_depth':[x for x in range(2, 10, 2)],
          'n_estimators': [x for x in range(10, 70, 10)]}

grid_rf_final = GridSearchCV(model_rf, 
                             parametrs, 
                             cv=5, 
                             scoring=smape_scorer)
grid_rf_final.fit(features_train, target_train_final)

print(grid_rf_final.best_params_)
print('Средняя оценка качества sMape_rougher берем по модулю', abs(grid_rf_final.best_score_))
# Out:
# {'max_depth': 4, 'n_estimators': 60}
# Средняя оценка качества sMape_rougher берем по модулю 8.962873466511772

# %%
total_smape = final_sMAPE_calc(abs(grid_rf_rougher.best_score_), abs(grid_rf_final.best_score_))
print('По модели случайный лес итоговое sMAPE =', total_smape)
# Out:
# По модели случайный лес итоговое sMAPE = 8.311183278498483

# %% [markdown]
# На тестовой выборке вычисляю final sMAPE по RandomForestRegressor:

# %%
#лучшая модель rougher
model_rf_best_rougher = RandomForestRegressor(random_state=12345, max_depth=6, n_estimators=50 )

#Для этапа rougher
#обучим модель (на трейне)
model_rf_best_rougher.fit(features_train, target_train_rougher)
#прогноз целевого признака
pred_test_rf_rougher = model_rf_best_rougher.predict(features_test)


#лучшая модель final
model_rf_best_final = RandomForestRegressor(random_state=12345, max_depth=4, n_estimators=60 )

#Для этапа final
#обучим модель (на трейне)
model_rf_best_final.fit(features_train, target_train_final)
#прогноз целевого признака
pred_test_rf_final = model_rf_best_final.predict(features_test)


smape_rougher = sMAPE_calc(target_test_rougher, pred_test_rf_rougher)
smape_final = sMAPE_calc(target_test_final, pred_test_rf_final)

total_smape_test = final_sMAPE_calc(abs(smape_rougher), abs(smape_final))


print('По модели случайный лес итоговое sMAPE на тестовой выборке =', total_smape_test)
# Out:
# По модели случайный лес итоговое sMAPE на тестовой выборке = 9.368302984841442

# %% [markdown]
# Вывод:
#
# На тренировочной выборке обучила 2 модели - случайный лес, и линейную регрессию - с применением кросс-валидации. Случайный лес показал лучшие метрики качества. Поэтому проверку на тестовой выборке провела на нем.
# Симметричная средняя абсолютная процентная ошибка на тестовой выборке - 9,37

# %% [markdown]
# Проверка модели на вменяемость

# %%
dummy_rougher = DummyRegressor(strategy='mean')
dummy_final = DummyRegressor(strategy='mean')
    
dummy_rougher.fit(features_train, target_train_rougher)
dummy_final.fit(features_train, target_train_final)
    
rougher = dummy_rougher.predict(df_test)
final = dummy_final.predict(df_test)
    
final_smape = final_sMAPE_calc(sMAPE_calc(target_test_rougher, rougher),
                                   sMAPE_calc(target_test_final, final))

print('Для стратегии', 'mean', 'итоговая sMAPE =', round(final_smape,3))
# Out:
# Для стратегии mean итоговая sMAPE = 9.832

# %% [markdown]
# Наша модель проходит проверку на вменяемость, симметричная средняя абсолютная процентная ошибка на тестовой выборке - 9,37, что меньше 9,83

# %% [markdown]
# ## 4. Вывод:

# %% [markdown]
# Лучшей моделью является RandomForestRegressor, так как эта модель предсказывает коэффициент восстановления золота из золотосодержащей руды наилучшим образом, в том числе при проверке на вменяемость.
